# %%
import json
import pandas as pd

with open('estat_sdg_05_20_filtered_en.json') as f:
    data = json.load(f)

data.keys()
# Out:
# dict_keys(['version', 'class', 'label', 'source', 'updated', 'value', 'status', 'id', 'size', 'dimension', 'extension'])

# %%
import pandas as pd

df = pd.read_csv("earn_gr_gpgr2ag$defaultview_linear.csv")

df.head()
# Out:
#                                  DATAFLOW        LAST UPDATE    freq  \
# 0  ESTAT:EARN_GR_GPGR2AG$DEFAULTVIEW(1.0)  02/03/26 23:00:00  Annual
# 1  ESTAT:EARN_GR_GPGR2AG$DEFAULTVIEW(1.0)  02/03/26 23:00:00  Annual
# 2  ESTAT:EARN_GR_GPGR2AG$DEFAULTVIEW(1.0)  02/03/26 23:00:00  Annual
# 3  ESTAT:EARN_GR_GPGR2AG$DEFAULTVIEW(1.0)  02/03/26 23:00:00  Annual
# 4  ESTAT:EARN_GR_GPGR2AG$DEFAULTVIEW(1.0)  02/03/26 23:00:00  Annual
#
#          unit                 age      geo  TIME_PERIOD  OBS_VALUE OBS_FLAG  \
# 0  Percentage  Less than 25 years  Albania         2018        0.3      NaN
# 1  Percentage  Less than 25 years  Austria         2018        7.7      NaN
# 2  Percentage  Less than 25 years  Austria         2022        9.1      NaN
# 3  Percentage  Less than 25 years  Belgium         2015       -1.4      NaN
# 4  Percentage  Less than 25 years  Belgium         2016       -0.8      NaN
#
#    CONF_STATUS
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# ...
